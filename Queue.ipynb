# %% [markdown]
# <a href="https://colab.research.google.com/github/akhiranandhinibandi/madam_python_2026/blob/main/Queue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#QUEUE
queue=[]
queue.insert(0,10)
queue.insert(0,20)
queue.insert(0,30)
#queue.pop()

# %%
queue
# Out:
# [30, 20, 10]

# %%
queue.pop()
# Out:
# 20

# %%
class Q:
  def __init__(self):
    self.q=[]
  def enqueue(self,d):
    self.q.insert(0,d)
  def dequeue(self):
    self.q.pop()
  #def print(self)
queue=Q()
queue.enqueue(10)
queue.enqueue(30)
queue.enqueue(40)
queue.enqueue(50)
queue.q
# Out:
# [50, 40, 30, 10]

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

class Queue:

    def __init__(self):
        self.front=None
        self.rear=None

    def enqueue(self,data):
        new_node=Node(data)
        if self.rear is None:
            self.front=self.rear=new_node
            return
        self.rear.next=new_node
        self.rear=new_node

    def dequeue(self):
        if self.front is None:
            print("Queue is Empty")
            return
        temp=self.front
        self.front=temp.next
        if self.front is None:
          self.rear=None
        print(f"{temp.data}removed")
    def display(self):
      temp=self.front
      while temp:
        print(temp.data,end="->")
        temp=temp.next
      print("None")
q=Queue()
q.enqueue(1)
q.enqueue(2)
q.enqueue(3)
q.display()
q.dequeue()

# %%
from collections import deque
q=deque()
q.append(10)
q.append(20)
q.append(30)
q.append(40)
print(q)
q.popleft()
print(q)
print("Front:",q[0])
# Out:
# deque([10, 20, 30, 40])
# deque([20, 30, 40])
# Front: 20

# %%
from collections import deque
q=deque()
q.appendleft(10)
q.appendleft(20)
q.appendleft(30)
q.appendleft(40)
print(q)
q.pop()
print(q)
print("Front:",q[0])
# Out:
# deque([40, 30, 20, 10])
# deque([40, 30, 20])
# Front: 40
