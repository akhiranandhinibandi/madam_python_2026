# %% [markdown]
# <a href="https://colab.research.google.com/github/akhiranandhinibandi/madam_python_2026/blob/main/stack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#stack implementation using arrays
stack=[]
stack.append("https://leetcode.com/problemset/")
stack.append("https://leetcode.com/contest/")
stack.append("https://leetcode.com/discuss/")
stack.append("https://leetcode.com/explore/")
print(stack)
print(stack.pop())
# Out:
# ['https://leetcode.com/problemset/', 'https://leetcode.com/contest/', 'https://leetcode.com/discuss/', 'https://leetcode.com/explore/']
# https://leetcode.com/explore/

# %%
#using functions
class Stack:
    def __init__(self):
        self.stack = []   # internal list to store elements

    # PUSH operation
    def push(self, value):
        self.stack.append(value)

    # POP operation
    def pop(self):
        if self.is_empty():
            print("Stack is empty. Cannot pop.")
            return None
        return self.stack.pop()

    # PEEK (top element)
    def peek(self):
        if self.is_empty():
            return None
        return self.stack[-1]
    def is_empty(self):
        return len(self.stack) == 0
    def display(self):
        print(self.stack)

# %%
#using linked lists
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None


class Stack:
    def __init__(self):
        self.top=None

    def push(self,data):
        new_node=Node(data)
        new_node.next=self.top
        self.top=new_node
        print(data,"Pushed  into stack")


    def pop(self):
        if self.isEmpty():
            print("Stack is Underflow-cannot pop")
            return None

        popped_value=self.top.data
        self.top=self.top.next
        print(popped_value,"popped from stack")
        return popped_value

    def peek(self):
        if self.isEmpty():
            print("stack is empty")
            return None
        return self.top.data

    def isEmpty(self):
        return self.top is None

    def display(self):
        if self.isEmpty():
            print("Stack is Empty")
            return

        temp=self.top
        print("Stack Elements (Top to Bottom)")
        while temp:
            print(temp.data)
            temp=temp.next

s=Stack()
s.push(10)
s.push(20)
s.push(30)
s.push(40)
print()
s.pop()
# Out:
# 10 Pushed  into stack
# 20 Pushed  into stack
# 30 Pushed  into stack
# 40 Pushed  into stack
#
# 40 popped from stack
# 40
